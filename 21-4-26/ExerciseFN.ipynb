# %%
import pandas as pd

# %%
data = {
    "Name": ["Rahul", "Sneha", "Arjun", "Priya", "Karan"],
    "Salary": [45000, 60000, 52000, 48000, 70000],
    "Department": ["HR", "IT", "Finance", "IT", "HR"]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Salary Department
# 0  Rahul   45000         HR
# 1  Sneha   60000         IT
# 2  Arjun   52000    Finance
# 3  Priya   48000         IT
# 4  Karan   70000         HR

# %%
df[["Name", "Salary"]]
# Out:
#     Name  Salary
# 0  Rahul   45000
# 1  Sneha   60000
# 2  Arjun   52000
# 3  Priya   48000
# 4  Karan   70000

# %%
df[df["Salary"] > 50000]
# Out:
#     Name  Salary Department
# 1  Sneha   60000         IT
# 2  Arjun   52000    Finance
# 4  Karan   70000         HR

# %%
df.groupby("Department").size()
# Out:
# Department
# Finance    1
# HR         2
# IT         2
# dtype: int64

# %%
df.sort_values(by="Salary")
# Out:
#     Name  Salary Department
# 0  Rahul   45000         HR
# 3  Priya   48000         IT
# 2  Arjun   52000    Finance
# 1  Sneha   60000         IT
# 4  Karan   70000         HR
